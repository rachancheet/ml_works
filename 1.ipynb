# %%
import numpy as np

arr = np.array([1, 2, 3, 6, 4, 5])
reversed_arr = arr[::-1]
print(reversed_arr)


array1 = np.array([[1, 2, 3], [2, 4, 5], [1, 2, 3]])

# Method 1: Using flatten()
flattened_array1 = array1.flatten()

# Method 2: Using ravel()
flattened_array2 = array1.ravel()

print(flattened_array1)
print(flattened_array2)


arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[1, 2], [3, 4]])

comparison = np.array_equal(arr1, arr2)
print(comparison)
# For x
x = np.array([1, 2, 3, 4, 5, 1, 2, 1, 1, 1])
most_frequent_x = np.bincount(x).argmax()
indices_x = np.where(x == most_frequent_x)[0]

print(f"Most frequent value in x: {most_frequent_x}, Indices: {indices_x}")

# For y
y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3])
most_frequent_y = np.bincount(y).argmax()
indices_y = np.where(y == most_frequent_y)[0]

print(f"Most frequent value in y: {most_frequent_y}, Indices: {indices_y}")
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

# i. Sum of all elements
sum_all = gfg.sum()

# ii. Sum of all elements row-wise
sum_rows = gfg.sum(axis=1)

# iii. Sum of all elements column-wise
sum_columns = gfg.sum(axis=0)

print(f"Sum of all elements: {sum_all}")
print(f"Row-wise sum: {sum_rows}")
print(f"Column-wise sum: {sum_columns}")
n_array = np.array([[55, 25, 15], [30, 44, 2], [11, 45, 77]])

# i. Sum of diagonal elements
diagonal_sum = np.trace(n_array)

# ii. Eigen values of matrix
eigen_values = np.linalg.eigvals(n_array)

# iii. Eigen vectors of matrix
eigen_values, eigen_vectors = np.linalg.eig(n_array)

# iv. Inverse of matrix
inverse_matrix = np.linalg.inv(n_array)

# v. Determinant of matrix
determinant = np.linalg.det(n_array)

print(f"Diagonal sum: {diagonal_sum}")
print(f"Eigen values: {eigen_values}")
print(f"Eigen vectors: \n{eigen_vectors}")
print(f"Inverse of matrix: \n{inverse_matrix}")
print(f"Determinant: {determinant}")
# i. First pair of matrices
p1 = np.array([[1, 2], [2, 3]])
q1 = np.array([[4, 5], [6, 7]])

product_1 = np.dot(p1, q1)
covariance_1 = np.cov(p1.flatten(), q1.flatten())

print(f"Product of p1 and q1:\n{product_1}")
print(f"Covariance between p1 and q1:\n{covariance_1}")

# ii. Second pair of matrices
p2 = np.array([[1, 2], [2, 3], [4, 5]])
q2 = np.array([[4, 5, 1], [6, 7, 2]])

product_2 = np.dot(p2, q2)
covariance_2 = np.cov(p2.flatten(), q2.flatten())

print(f"Product of p2 and q2:\n{product_2}")
print(f"Covariance between p2 and q2:\n{covariance_2}")
x = np.array([[2, 3, 4], [3, 2, 9]])
y = np.array([[1, 5, 0], [5, 10, 3]])

# Inner product
inner_product = np.inner(x, y)

# Outer product
outer_product = np.outer(x, y)

# Cartesian product
cartesian_product = np.dot(x, y.T)

print(f"Inner product:\n{inner_product}")
print(f"Outer product:\n{outer_product}")
print(f"Cartesian product:\n{cartesian_product}")

array = np.array([[1, -2, 3], [-4, 5, -6]])

# i. Element-wise absolute value
absolute_values = np.abs(array)

# ii. Percentiles
percentiles = np.percentile(array, [25, 50, 75], axis=None)
percentiles_columns = np.percentile(array, [25, 50, 75], axis=0)
percentiles_rows = np.percentile(array, [25, 50, 75], axis=1)

# iii. Mean, Median, and Standard Deviation
mean_value = np.mean(array)
median_value = np.median(array)
std_deviation = np.std(array)

mean_columns = np.mean(array, axis=0)
median_columns = np.median(array, axis=0)
std_deviation_columns = np.std(array, axis=0)

mean_rows = np.mean(array, axis=1)
median_rows = np.median(array, axis=1)
std_deviation_rows = np.std(array, axis=1)

print(f"Absolute values:\n{absolute_values}")
print(f"Percentiles:\n{percentiles}")
print(f"Mean: {mean_value}, Median: {median_value}, Std Dev: {std_deviation}")
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

# Floor, Ceiling, Truncated, and Rounded values
floor_values = np.floor(a)
ceiling_values = np.ceil(a)
truncated_values = np.trunc(a)
rounded_values = np.round(a)

print(f"Floor values: {floor_values}")
print(f"Ceiling values: {ceiling_values}")
print(f"Truncated values: {truncated_values}")
print(f"Rounded values: {rounded_values}")
```

array = np.array([10, 52, 62, 16, 16, 54, 453])

# i. Sorted array
sorted_array = np.sort(array)

# ii. Indices of sorted array
sorted_indices = np.argsort(array)

# iii. 4 smallest elements
smallest_elements = np.partition(array, 4)[:4]

# iv. 5 largest elements
largest_elements = np.partition(array, -5)[-5:]

print(f"Sorted array: {sorted_array}")
print(f"Indices of sorted array: {sorted_indices}")
print(f"4 smallest elements: {smallest_elements}")
print(f"5 largest elements: {largest_elements}")
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

# i. Integer elements only
integer_elements = array[array == array.astype(int)]

# ii. Float elements only
float_elements = array[array != array.astype(int)]

print(f"Integer elements: {integer_elements}")
print(f"Float elements: {float_elements}")


from PIL import Image
import numpy as np

def img_to_array(path):
    img = Image.open(path)
    img_array = np.array(img)
    
    if len(img_array.shape) == 2:  # Grayscale
        np.savetxt("image_greyscale.txt", img_array, fmt='%d')
    else:  # RGB
        r, g, b = img_array[:,:,0], img_array[:,:,1], img_array[:,:,2]
        np.savetxt("image_r.txt", r, fmt='%d')
        np.savetxt("image_g.txt", g, fmt='%d')
        np.savetxt("image_b.txt", b, fmt='%d')

# Usage
img_to_array('path_to_image.jpg')

# For Greyscale Image
greyscale_image = np.loadtxt("image_greyscale.txt", dtype=int)
print(greyscale_image)

# For RGB Image (assuming all channels were saved)
r = np.loadtxt("image_r.txt", dtype=int)
g = np.loadtxt("image_g.txt", dtype=int)
b = np.loadtxt("image_b.txt", dtype=int)

rgb_image = np.stack((r, g, b), axis=-1)
print(rgb_image)
